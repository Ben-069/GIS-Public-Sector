# %% [markdown]
# <a href="https://colab.research.google.com/github/Ben-069/GIS-Public-Sector/blob/main/BenitoGISAssigment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Student: Benito Ortega Torres

# %% [markdown]
# I come from a very rural country and there is a huge incidence from agriculture and cattle raising on the GDP. Despite of that, most of the food comes from a traditional production system which is killing our natural resources fast. So my idea is to help non profits and even the government to create sustainable programs-policies that will encourage farmers on the transition to sustainable farming.
#
# The best way to work on that problem that I mentioned before is to identify those places where people practice: traditional agriculture or cattle raising, sophisticated or precistion agriculture, organic-agroecological farms, and small-scale farmers. This will be an essential tool on kwowing where are the communities and areas of work.

# %%
# %%capture
# !pip install geopandas==1.0.1
# !pip install mapclassify

# %%
import os, zipfile #basics
import pandas as pd #data management
import matplotlib.pyplot as plt #vis

import geopandas as gpd #gis/maps: a sister of pandas; does the job;
#tho not as fancy-interactive as folium or leafmap https://geopandas.org/

import mapclassify #need for thematic map classification

#will display all output not just last command
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from google.colab import files #to download from colab onto hd

from google.colab import data_table
data_table.enable_dataframe_formatter() #this enables spreadsheet view upon calling dataframe (without() )

# %%
#!python --version
gpd.__version__
# Out:
# '1.0.1'

# %%
#i found one and reposted on my website, download it onto colab:
! wget -q -O paraguay-boundaries.zip https://docs.google.com/uc?id=1_U-qJpLcgue3uCwKoL1YOk8eY1yPsHb1&export=download

zip_ref = zipfile.ZipFile('paraguay-boundaries.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
parbC0=gpd.read_file('geoBoundaries-PRY-ADM0_simplified.shp') #load the shapefile with gpd as njC

# %%
#make the map
parbC0.plot()
# Out:
# <Axes: >

# %%
# %%capture
# !pip install geopandas==1.0.1
# !pip install mapclassify

# %%
import os, zipfile #basics
import pandas as pd #data management
import matplotlib.pyplot as plt #vis

import geopandas as gpd #gis/maps: a sister of pandas; does the job;
#tho not as fancy-interactive as folium or leafmap https://geopandas.org/

import mapclassify #need for thematic map classification

#will display all output not just last command
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from google.colab import files #to download from colab onto hd

from google.colab import data_table
data_table.enable_dataframe_formatter() #this enables spreadsheet view upon calling dataframe (without() )

# %%
#!python --version
gpd.__version__
# Out:
# '1.0.1'

# %%
#i found one and reposted on my website, download it onto colab:
! wget -q -O paraguay-natresources.zip https://docs.google.com/uc?id=1dE77C_-QdsSSu60eSVXtJsWuwBPzJWWW&export=download

zip_ref = zipfile.ZipFile('paraguay-natresources.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
parnatC0=gpd.read_file('par_gc_adg_1.shp') #load the shapefile with gpd as njC

# %%
#make the map
parnatC0.plot()
# Out:
# <Axes: >

# %% [markdown]
# I found this other map that was supposed to be the natural resources of Paraguay! There are some visible patterns, that I presume are natural parks or forested areas. Is there any way to make this clearer?
